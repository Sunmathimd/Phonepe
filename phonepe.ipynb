# %%
import pandas as pd
import mysql.connector as sql
import streamlit as st
import plotly.express as px
import os
import json
from PIL import Image
import os

# %%
import mysql.connector

# %%
# CONNECTING WITH MYSQL DATABASE
mydb = sql.connect(host="127.0.0.1",
                   user="root",
                   password="",
                   #database= "phonepe",
                   port = "3306"
                  )
mycursor = mydb.cursor(buffered=True)

# %%
# Creating new database and tables
mycursor.execute("CREATE DATABASE IF NOT EXISTS phonepe")
mycursor.execute("USE phonepe")

# %%
# Creating agg_trans table
mycursor.execute("create table if not exists agg_trans (State varchar(100), Year int, Quarter int, Transaction_type varchar(100), Transaction_count int, Transaction_amount double)")

for i,row in agg_trans.iterrows():
    #here %S means string values 
    sql = "INSERT INTO agg_trans VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    # the connection is not auto committed by default, so we must commit to save our changes
    mydb.commit()

# %%
agg_trans = pd.read_csv("agg_trans.csv")
agg_trans
# Out:
#        State  Year  Quarter          Transaction_type  Transaction_count  \
# 0     kerala  2022        3         Merchant payments           64984061
# 1     kerala  2022        3     Peer-to-peer payments           38774832
# 2     kerala  2022        3  Recharge & bill payments           15289755
# 3     kerala  2022        3        Financial Services             146673
# 4     kerala  2022        3                    Others             167583
# ...      ...   ...      ...                       ...                ...
# 4129  sikkim  2023        1     Peer-to-peer payments            1779090
# 4130  sikkim  2023        1         Merchant payments            1067585
# 4131  sikkim  2023        1  Recharge & bill payments             543957
# 4132  sikkim  2023        1        Financial Services               2603
# 4133  sikkim  2023        1                    Others               2893
#
#       Transaction_amount
# 0           3.785276e+10
# 1           1.164140e+11
# 2           7.709237e+09
# 3           1.628616e+08
# 4           1.215572e+08
# ...                  ...
# 4129        5.451627e+09
# 4130        1.091745e+09
# 4131        2.135177e+08
# 4132        2.801184e+06
# 4133        2.877504e+06
#
# [4134 rows x 6 columns]

# %%
# Creating agg_user table
mycursor.execute("create table agg_user (State varchar(100), Year int, Quarter int, Brands varchar(100), Count int, Percentage double)")

for i,row in agg_user.iterrows():
    sql = "INSERT INTO agg_user VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()

# %%
agg_user = pd.read_csv("agg_user.csv")
agg_user
# Out:
#        State  Year  Quarter    Brands    Count  Percentage
# 0     kerala  2022        1    Xiaomi  2098370    0.233872
# 1     kerala  2022        1   Samsung  1826034    0.203519
# 2     kerala  2022        1      Vivo  1330622    0.148303
# 3     kerala  2022        1      Oppo  1032233    0.115047
# 4     kerala  2022        1    Realme   705424    0.078622
# ...      ...   ...      ...       ...      ...         ...
# 6727  sikkim  2018        4  Motorola     1119    0.023054
# 6728  sikkim  2018        4    Lenovo     1038    0.021385
# 6729  sikkim  2018        4   OnePlus      969    0.019964
# 6730  sikkim  2018        4    Huawei      689    0.014195
# 6731  sikkim  2018        4    Others     4877    0.100478
#
# [6732 rows x 6 columns]

# %%
# Creating map_trans table
mycursor.execute("create table map_trans (State varchar(100), Year int, Quarter int, District varchar(100), Count int, Amount double)")

for i,row in map_trans.iterrows():
    sql = "INSERT INTO map_trans VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()

# %%
map_trans = pd.read_csv("map_trans.csv")
map_trans
# Out:
#         State  Year  Quarter                     District     Count  \
# 0      kerala  2022        3  thiruvananthapuram district  11886964
# 1      kerala  2022        3           kasaragod district   2816269
# 2      kerala  2022        3          malappuram district  11727280
# 3      kerala  2022        3      pathanamthitta district   2373258
# 4      kerala  2022        3             wayanad district   3269014
# ...       ...   ...      ...                          ...       ...
# 16827  sikkim  2023        2               north district    396867
# 16828  sikkim  2023        1               south district    686864
# 16829  sikkim  2023        1                west district    368967
# 16830  sikkim  2023        1                east district   2050840
# 16831  sikkim  2023        1               north district    289457
#
#              Amount
# 0      1.663731e+10
# 1      4.420477e+09
# 2      1.543540e+10
# 3      3.615274e+09
# 4      4.610463e+09
# ...             ...
# 16827  9.900944e+08
# 16828  1.130114e+09
# 16829  8.535045e+08
# 16830  4.070142e+09
# 16831  7.088070e+08
#
# [16832 rows x 6 columns]

# %%
# Creating map_user table
mycursor.execute("create table map_user (State varchar(100), Year int, Quarter int, District varchar(100), Registered_user int, App_opens int)")

for i,row in map_user.iterrows():
    sql = "INSERT INTO map_user VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()

# %%
map_user = pd.read_csv("map_user.csv")
map_user
# Out:
#         State  Year  Quarter                     District  RegisteredUser  \
# 0      kerala  2022        3  thiruvananthapuram district         1095580
# 1      kerala  2022        3           kasaragod district          325218
# 2      kerala  2022        3          malappuram district          961854
# 3      kerala  2022        3      pathanamthitta district          301025
# 4      kerala  2022        3             wayanad district          259233
# ...       ...   ...      ...                          ...             ...
# 16831  sikkim  2023        2               north district           22291
# 16832  sikkim  2023        1               south district           52942
# 16833  sikkim  2023        1                west district           32945
# 16834  sikkim  2023        1                east district          145199
# 16835  sikkim  2023        1               north district           21354
#
#        AppOpens
# 0       5022977
# 1       6664472
# 2      10102534
# 3       3433193
# 4       7609643
# ...         ...
# 16831   6870467
# 16832   5195700
# 16833   4025814
# 16834   4158937
# 16835   5546776
#
# [16836 rows x 6 columns]

# %%
# Creating top_trans table
mycursor.execute("create table top_trans (State varchar(100), Year int, Quarter int, Pincode int, Transaction_count int, Transaction_amount double)")

for i,row in top_trans.iterrows():
    sql = "INSERT INTO top_trans VALUES (%s,%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File c:\Users\sunma\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py:633, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     632         query = query.encode("utf-8")
# --> 633     self._cmysql.query(
#     634         query,
#     635         raw=raw,
#     636         buffered=buffered,
#     637         raw_as_string=raw_as_string,
#     638         query_attrs=self.query_attrs,
#     639     )
#     640 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Unknown column 'nan' in 'field list'
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# c:\Users\sunma\OneDrive\Documents\Vscode1\phonepe.ipynb Cell 13 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/sunma/OneDrive/Documents/Vscode1/phonepe.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> for i,row in top_trans.iterrows():
#       <a href='vscode-notebook-cell:/c%3A/Users/sunma/OneDrive/Documents/Vscode1/phonepe.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a>     sql = "INSERT INTO top_trans VALUES (%s,%s,%s,%s,%s,%s)"
# ----> <a href='vscode-notebook-cell:/c%3A/Users/sunma/OneDrive/Documents/Vscode1/phonepe.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a>     mycursor.execute(sql, tuple(row))
#       <a href='vscode-notebook-cell:/c%3A/Users/sunma/OneDrive/Documents/Vscode1/phonepe.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a>     mydb.commit()
#
# File c:\Users\sunma\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\cursor_cext.py:330, in CMySQLCursor.execute(self, operation, params, multi)
#     325             raise ProgrammingError(
#     326                 "Not all parameters were used in the SQL statement"
#     327             )
#     329 try:
# --> 330     result = self._cnx.cmd_query(
#     331         stmt,
#     332         raw=self._raw,
#     333         buffered=self._buffered,
#     334         raw_as_string=self._raw_as_string,
#     335     )
#     336 except MySQLInterfaceError as err:
#     337     raise get_mysql_exception(
#     338         msg=err.msg, errno=err.errno, sqlstate=err.sqlstate
#     339     ) from err
#
# File c:\Users\sunma\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\opentelemetry\context_propagation.py:77, in with_context_propagation.<locals>.wrapper(cnx, *args, **kwargs)
#      75 """Context propagation decorator."""
#      76 if not OTEL_ENABLED or not cnx.otel_context_propagation:
# ---> 77     return method(cnx, *args, **kwargs)
#      79 current_span = trace.get_current_span()
#      80 tp_header = None
#
# File c:\Users\sunma\AppData\Local\Programs\Python\Python310\lib\site-packages\mysql\connector\connection_cext.py:641, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     633     self._cmysql.query(
#     634         query,
#     635         raw=raw,
#    (...)
#     638         query_attrs=self.query_attrs,
#     639     )
#     640 except MySQLInterfaceError as err:
# --> 641     raise get_mysql_exception(
#     642         err.errno, msg=err.msg, sqlstate=err.sqlstate
#     643     ) from err
#     644 except AttributeError as err:
#     645     addr = (
#     646         self._unix_socket if self._unix_socket else f"{self._host}:{self._port}"
#     647     )
#
# ProgrammingError: 1054 (42S22): Unknown column 'nan' in 'field list'

# %%
top_trans = pd.read_csv("top_trans.csv")
top_trans
# Out:
#        State  Year  Quarter   Pincode  Transaction_count  Transaction_amount
# 0     kerala  2022        3  682036.0            7957281        8.882655e+09
# 1     kerala  2022        3  682507.0            6910583        8.367756e+09
# 2     kerala  2022        3  695001.0            3499068        4.575184e+09
# 3     kerala  2022        3  680001.0            2995750        4.099707e+09
# 4     kerala  2022        3  691001.0            2214879        3.098616e+09
# ...      ...   ...      ...       ...                ...                 ...
# 8205  sikkim  2023        1  737136.0             200108        2.438220e+08
# 8206  sikkim  2023        1  737126.0             193529        3.777742e+08
# 8207  sikkim  2023        1  737113.0             167423        4.270521e+08
# 8208  sikkim  2023        1  737120.0             158663        4.115426e+08
# 8209  sikkim  2023        1  737121.0             140021        2.758005e+08
#
# [8210 rows x 6 columns]

# %%
top_trans.isnull().sum()
# Out:
# State                 0
# Year                  0
# Quarter               0
# Pincode               2
# Transaction_count     0
# Transaction_amount    0
# dtype: int64

# %%
# Creating top_user table
mycursor.execute("create table top_user (State varchar(100), Year int, Quarter int, Pincode int, Registered_users int)")

for i,row in top_user.iterrows():
    sql = "INSERT INTO top_user VALUES (%s,%s,%s,%s,%s)"
    mycursor.execute(sql, tuple(row))
    mydb.commit()

# %%
top_user = pd.read_csv("top_user.csv")
top_user
# Out:
#        State  Year  Quarter  Pincode  RegisteredUsers
# 0     kerala  2022        3   682042            48385
# 1     kerala  2022        3   695001            48080
# 2     kerala  2022        3   682024            44605
# 3     kerala  2022        3   682025            41047
# 4     kerala  2022        3   682020            39537
# ...      ...   ...      ...      ...              ...
# 8206  sikkim  2023        1   737135            18992
# 8207  sikkim  2023        1   737113            14738
# 8208  sikkim  2023        1   737121            12726
# 8209  sikkim  2023        1   737120            11868
# 8210  sikkim  2023        1   737103            10158
#
# [8211 rows x 5 columns]

# %%
mycursor.execute('DROP DATABASE phonepe')
